# %% [markdown]
# <a href="https://colab.research.google.com/github/meghmodi2810/Machine-Learning-Projects/blob/main/GaussiaNB_IrisDataset_ScikitLearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = load_iris()

# %%
classifier = GaussianNB()
classifier.fit(dataset.data, dataset.target)
# Out:
# GaussianNB()

# %%
expected = dataset.target
predicted = classifier.predict(dataset.data)

# %%
confusion_matrix = confusion_matrix(expected, predicted)
print(confusion_matrix)
# Out:
# [[50  0  0]
#  [ 0 47  3]
#  [ 0  3 47]]

# %%
print(classification_report(expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       0.94      0.94      0.94        50
#            2       0.94      0.94      0.94        50
#
#     accuracy                           0.96       150
#    macro avg       0.96      0.96      0.96       150
# weighted avg       0.96      0.96      0.96       150

# %%
accuracy = accuracy_score(expected, predicted)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 96.00%

# %%
## plotting to visualize the data
plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Purples',
            xticklabels=dataset.target_names, yticklabels=dataset.target_names)
plt.title("Confusion Matrix - GaussianNB on Iris")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
